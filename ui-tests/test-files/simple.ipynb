# %% [markdown]
# # Simple export
#
# A heading, a paragraph, and a code cell with a text output.
#
# - first item
# - second item

# %%
print('Hello from the PDF exporter')
# Out:
# Hello from the PDF exporter

# %%
2 + 2
# Out:
# 4
