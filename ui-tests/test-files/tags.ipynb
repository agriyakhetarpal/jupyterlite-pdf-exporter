# %% [markdown]
# # Cell tags
#
# Cells in this notebook carry the tags that nbconvert and Jupyter Book use to leave things out of an export. The exporter should honour them, in both spellings.

# %%
print('kept-cell-source')
# Out:
# kept-cell-output

# %%
print('removed-input-source')
# Out:
# kept-output-of-hidden-input

# %%
print('kept-source-of-hidden-output')
# Out:
# removed-output-text

# %%
print('removed-cell-source')
# Out:
# removed-cell-output

# %% [markdown]
# This Markdown cell is tagged too and must not appear: removed-markdown-text

# %% [markdown]
# The last cell stays.
