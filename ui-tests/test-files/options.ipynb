# %% [markdown]
# # Export options
#
# This notebook is exported once per documented setting. Please see the [`jupyterlite-pdf-exporter` README](https://github.com/agriyakhetarpal/jupyterlite-pdf-exporter) for a description of each setting.

# %% [markdown]
# ## First section
#
# Some body text that runs long enough to show the effect of the margin, font size, main font, and line spacing settings.
#
# An example of a pangram is: "the quick brown fox jumps over the lazy dog". 0123456789!@#$%^&*()_+-=[]{}|;':",./<>?
#
# - Here's a bulleted item
# - Here's another bulleted item
#
# And this is some `inline code`, and a second paragraph to gauge line spacing.

# %% [markdown]
# ## Second section
#
# This is a second heading, to test the table of contents and section numbering settings.

# %%
print('output from a code cell. This is a stream output from print, so it has no Out prompt.')
# Out:
# output from a code cell. This is a stream output from print, so it has no Out prompt.

# %%
# A result gets an Out prompt
2 + 2
# Out:
# 4
