# %% [markdown]
# # Electromagnetism
#
# This test notebook describes Maxwell's equations in differential form, followed by a few standard results, as a means to test `text/latex` being exported into Typst math output.

# %% [markdown]
# ## Maxwell's equations

# %%
Math(r'\nabla \cdot \mathbf{E} = \frac{\rho}{\varepsilon_0}')
# Out:
# $\displaystyle \nabla \cdot \mathbf{E} = \frac{\rho}{\varepsilon_0}$

# %%
Math(r'\nabla \cdot \mathbf{B} = 0')
# Out:
# $\displaystyle \nabla \cdot \mathbf{B} = 0$

# %%
Math(r'\nabla \times \mathbf{E} = -\frac{\partial \mathbf{B}}{\partial t}')
# Out:
# $\displaystyle \nabla \times \mathbf{E} = -\frac{\partial \mathbf{B}}{\partial t}$

# %%
Math(r'\nabla \times \mathbf{B} = \mu_0 \mathbf{J} + \mu_0 \varepsilon_0 \frac{\partial \mathbf{E}}{\partial t}')
# Out:
# $\displaystyle \nabla \times \mathbf{B} = \mu_0 \mathbf{J} + \mu_0 \varepsilon_0 \frac{\partial \mathbf{E}}{\partial t}$

# %% [markdown]
# ## Wave equation and related results

# %%
Math(r'...')
# Out:
# $\displaystyle \nabla^2 \mathbf{E} - \mu_0 \varepsilon_0 \frac{\partial^2 \mathbf{E}}{\partial t^2} = \nabla \left( \nabla \cdot \mathbf{E} \right) - \nabla \times \left( \nabla \times \mathbf{E} \right) - \mu_0 \varepsilon_0 \frac{\partial^2 \mathbf{E}}{\partial t^2}$

# %%
Math(r'...')
# Out:
# $\displaystyle \mathbf{S} = \frac{1}{\mu_0} \left( \mathbf{E} \times \mathbf{B} \right), \qquad u = \frac{1}{2} \left( \varepsilon_0 \left| \mathbf{E} \right|^2 + \frac{1}{\mu_0} \left| \mathbf{B} \right|^2 \right)$

# %%
Math(r'...')
# Out:
# $\displaystyle i \hbar \frac{\partial}{\partial t} \Psi(\mathbf{r}, t) = \left[ -\frac{\hbar^2}{2m} \nabla^2 + V(\mathbf{r}, t) \right] \Psi(\mathbf{r}, t)$

# %%
Math(r'...')
# Out:
# $\displaystyle \oint_{\partial \Sigma} \mathbf{B} \cdot \mathrm{d}\boldsymbol{\ell} = \mu_0 \iint_{\Sigma} \left( \mathbf{J} + \varepsilon_0 \frac{\partial \mathbf{E}}{\partial t} \right) \cdot \mathrm{d}\mathbf{S}$
